# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik-karnam/FMML-Labs/blob/main/Module8_Lab3_FMML20210611.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-28 15:32:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   296MB/s    in 0.2s
#
# 2022-06-28 15:32:10 (296 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22775  1706.04632v1  Stochastic gradient MCMC (SG-MCMC) algorithms ...  stat
# 3377   1607.00662v1  A key goal of computer vision is to recover th...    cs
# 13779   1411.6757v9  Recurrent networks with transfer functions tha...    cs
# 37999   0910.1022v3  We develop the distance dependent Chinese rest...  stat
# 11688  1609.09196v1  Thanks to the rise of wearable and connected d...  stat
# ...             ...                                                ...   ...
# 30816  1801.05117v1  Motion blur is a fundamental problem in comput...    cs
# 29575  1709.08172v1  We propose a novel image retrieval framework f...    cs
# 13100  1602.01064v3  We propose minimum regret search (MRS), a nove...  stat
# 13035  1612.08406v2  The inference of correlated signal fields with...  stat
# 14476  cs/0102022v2  Home page of the workshop proceedings, with po...    cs
#
#                                                    title  year  \
# 22775  Stochastic Gradient MCMC Methods for Hidden Ma...  2017
# 3377   Unsupervised Learning of 3D Structure from Images  2016
# 13779         Echo State Condition at the Critical Point  2014
# 37999    Distance Dependent Chinese Restaurant Processes  2009
# 11688  EXTRACT: Strong Examples from Weakly-Labeled S...  2016
# ...                                                  ...   ...
# 30816  Reblur2Deblur: Deblurring Videos via Self-Supe...  2018
# 29575  Can Image Retrieval help Visual Saliency Detec...  2017
# 13100  Minimum Regret Search for Single- and Multi-Ta...  2016
# 13035  Correlated signal inference by free energy exp...  2016
# 14476  Finite-State Phonology: Proceedings of the 5th...  2001
#
#                                                 keywords
# 22775  [stochastic, algorithms, inference, assumption...
# 3377   [underlying, structure, observations, generati...
# 13779  [recurrent, functions, lipschitz, continuity, ...
# 37999  [dependent, restaurant, distributions, partiti...
# 11688  [connected, generated, unfortunately, extracti...
# ...                                                  ...
# 30816  [fundamental, inference, traditional, deblurri...
# 29575  [retrieval, framework, detection, information,...
# 13100  [acquisition, optimization, similarities, info...
# 13035  [inference, correlated, correlation, structure...
# 14476  [proceedings, individually, proceedings, phono...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22775    [stochastic, algorithms, inference, assumption...
# 3377     [underlying, structure, observations, generati...
# 13779    [recurrent, functions, lipschitz, continuity, ...
# 37999    [dependent, restaurant, distributions, partiti...
# 11688    [connected, generated, unfortunately, extracti...
#                                ...
# 21856    [causality, situations, uncertainty, causality...
# 36195    [cognitive, cognitive, performance, conditions...
# 11893    [structure, effective, dimensionality, paramet...
# 11769    [approximating, decomposition, iteration, sati...
# 32901    [recommendation, algorithms, challenging, reco...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8718 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d188cbcc-6447-4431-be70-853d340d2835" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d188cbcc-6447-4431-be70-853d340d2835")) {                    Plotly.newPlot(                        "d188cbcc-6447-4431-be70-853d340d2835",                        [{"x":["parameters","stochastic","considering","likelihood","experiments","effectiveness","recording","dependent","algorithm","harnesses","outperforming","algorithms","synthetic","assumption","significantly","demonstrate","dependencies","representation","challenges","inference","structures","benchmarks","including","demonstrates","likelihoods","probabilistic","structure","observations","generative","literature","feasibility","unsupervised","representations","establish","underlying","mathematical","conditions","continuity","suggested","recurrent","limitations","achievement","illustrate","condition","definition","manuscript","lipschitz","connectivity","sufficient","determining","functions","sequential","alternative","formulation","properties","processes","distributions","connections","clustering","exchangeability","partitions","performance","nonparametric","restaurant","traditional","precision","knowledge","automatically","generated","consumption","evaluation","connected","identifying","arrangement","variables","typically","introduce","available","unfortunately","extracting","challenging","technique","prediction","dynamically","coefficients","presented","segmentation","regularities","different","adjusting","discretization","extraction","conceptual","incremental","resulting","hierarchical","complexity","statistical","instantaneous","frequency","isolation","robustness","instantaneously","detection","boltzmann","introduced","increased","importantly","computational","consequence","ubiquitous","regression","extensive","producing","essentially","recursive","splitting","framework","validation","manifests","simulation","validated","categorical","approaches","fundamental","predictive","following","selection","performing","contribute","important","assumptions","classification","inability","reasonable","categories","selecting","partitioning","replacing","informative","overfitting","precludes","factorization","filtering","collaborative","simplicity","exploiting","bandwidth","dimensional","recommendations","connection","efficient","differential","implementation","posterior","differentially","increases","applications","conventional","information","discrimination","indicates","categorization","divergence","monotonically","potential","generalization","numerically","tightness","approximations","techniques","approximation","maximizing","submodular","increasing","submodularity","variational","constrained","distribution","decomposes","maximized","treewidth","relationship","extensions","factorizing","relaxation","difference","guarantees","graphical","minimized","entropies","preparing","egocentric","appearance","assistive","distinguishes","interactions","collected","indicating","displayed"],"y":[216,136,75,57,616,228,9,72,782,3,23,615,149,63,269,599,51,382,119,197,125,87,267,59,3,157,332,62,119,116,31,145,241,59,112,71,155,8,26,131,72,5,60,60,54,7,4,17,92,27,243,74,105,85,215,86,120,42,156,2,10,898,17,1,175,64,356,194,143,19,276,66,66,3,126,101,378,271,29,65,277,239,222,28,37,179,191,7,749,4,3,130,25,31,138,106,223,157,3,67,9,93,3,328,27,137,35,26,275,20,21,124,165,19,22,24,13,557,51,2,78,48,14,429,92,56,77,164,94,31,364,75,478,2,35,72,46,21,14,39,23,0,34,70,41,15,83,10,202,23,39,403,38,110,31,5,35,400,98,680,23,20,23,26,3,169,125,11,4,35,369,115,22,12,98,3,52,62,218,11,4,5,76,43,3,22,57,56,59,18,5,5,8,73,2,5,81,76,15,5],"type":"bar"},{"x":["parameters","stochastic","considering","likelihood","experiments","effecti ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8158333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Modeling</span> <span style=''>and</span> <span style=''>Control</span> <span style=''>with</span> <span style=''>Local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Linearizing</span> <span style=''>Nadaraya</span> <span style=''>Watson</span> <span style='background-color:rgba(255, 0, 0, 0.49898989898989893);'>Regression</span> <br/><br/><span style=''>Black</span> <span style=''>box</span> <span style=''>models</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technical</span> <span style=''>systems</span> <span style=''>are</span> <span style=''>purely</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>descriptive</span> <span style=''>They</span> <span style=''>do</span> <span style=''>not</span> <span style=''>explain</span> <span style=''>why</span> <span style=''>a</span> <span style=''>system</span> <span style=''>works</span> <span style=''>the</span> <span style=''>way</span> <span style=''>it</span> <span style=''>does</span> <span style=''>Thus</span> <span style=''>black</span> <span style=''>box</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>insufficient</span> <span style=''>for</span> <span style=''>some</span> <span style=''>problems</span> <span style=''>But</span> <span style=''>there</span> <span style=''>are</span> <span style=''>numerous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>for</span> <span style=''>example</span> <span style=''>in</span> <span style=''>control</span> <span style='background-color:rgba(0, 255, 0, 0.34146341463414637);'>engineering</span> <span style=''>for</span> <span style=''>which</span> <span style=''>a</span> <span style=''>black</span> <span style=''>box</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>absolutely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3233830845771144);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>with</span> <span style=''>which</span> <span style=''>such</span> <span style=''>models</span> <span style=''>can</span> <span style=''>be</span> <span style=''>built</span> <span style=''>easily</span> <span style=''>and</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.48031496062992113);'>automated</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>give</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>example</span> <span style=''>and</span> <span style=''>show</span> <span style=''>how</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>model</span> <span style=''>and</span> <span style=''>control</span> <span style=''>a</span> <span style=''>motorcar</span> <span style=''>powertrain</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Modern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>methods</span> <span style=''>often</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>uniform</span> <span style=''>sampling</span> <span style=''>which</span> <span style=''>is</span> <span style=''>agnostic</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>This</span> <span style=''>might</span> <span style=''>degrade</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>by</span> <span style=''>yielding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>that</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>a</span> <span style=''>high</span> <span style=''>variance</span> <span style=''>A</span> <span style=''>possible</span> <span style=''>remedy</span> <span style=''>is</span> <span style=''>to</span> <span style=''>employ</span> <span style=''>non</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>which</span> <span style=''>take</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>into</span> <span style=''>account</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>a</span> <span style=''>recently</span> <span style=''>proposed</span> <span style=''>setting</span> <span style=''>which</span> <span style=''>poses</span> <span style=''>variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>as</span> <span style=''>an</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>bandit</span> <span style=''>feedback</span> <span style=''>We</span> <span style=''>devise</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>that</span> <span style=''>finds</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>with</span> <span style=''>the</span> <span style=''>best</span> <span style=''>fixed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hindsight</span> <span style=''>the</span> <span style=''>first</span> <span style=''>result</span> <span style=''>o ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Exact</span> <span style=''>Hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.6101694915254239);'>Covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3061224489795919);'>Thresholding</span> <span style=''>for</span> <span style=''>Joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>Lasso</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.40096618357487923);'>estimating</span> <span style=''>multiple</span> <span style=''>related</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>from</span> <span style=''>a</span> <span style=''>p</span> <span style='background-color:rgba(255, 0, 0, 0.31871838111298484);'>dimensional</span> <span style=''>dataset</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>consisting</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.34954954954954953);'>different</span> <span style=''>classes</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>is</span> <span style=''>based</span> <span style=''>upon</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>group</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>lasso</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.6101694915254239);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3061224489795919);'>thresholding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectively</span> <span style=''>identify</span> <span style=''>zero</span> <span style=''>entries</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>matrices</span> <span style=''>and</span> <span style=''>split</span> <span style=''>a</span> <span style=''>large</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>lasso</span> <span style=''>problem</span> <span style=''>into</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subproblems</span> <span style=''>Our</span> <span style=''>hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.6101694915254239);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3061224489795919);'>thresholding</span> <span style=''>method</span> <span style=''>is</span> <span style=''>superior</span> <span style=''>to</span> <span style=''>existing</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3061224489795919);'>thresholding</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style=''>split</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>class</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.34954954954954953);'>different</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Top</span> <span style=''>k</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiclass</span> <span style=''>SVM</span> <br/><br/><span style=''>Class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ambiguity</span> <span style=''>is</span> <span style=''>typical</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>When</span> <span style=''>classes</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminate</span> <span style=''>it</span> <span style=''>makes</span> <span style=''>sense</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>k</span> <span style=''>guesses</span> <span style=''>and</span> <span style=''>evaluate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>error</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>zero</span> <span style=''>one</span> <span style=''>loss</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>SVM</span> <span style=''>as</span> <span style=''>a</span> <span style=''>direct</span> <span style=''>method</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>for</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>SVM</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>tight</span> <span style=''>convex</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>of</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>error</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>scheme</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>onto</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>simplex</span> <span style=''>which</span> <span style=''>is</span> <span style=''>of</span> <span style=''>its</span> <span style=''>own</span> <span style=''>interest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>five</span> <span style=''>datasets</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>in</span> <span style=''>top</span> <span style=''>k</span> <span style=''>accuracy</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3); ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09996391194514616)
# 	segmentation (0.06892818477084085)
# 	experimental (0.1356910862504511)
# 	evaluation (0.09960303139660773)
# 	information (0.24539877300613497)
# 	detection (0.11836881992060629)
# 	representation (0.1378563695416817)
# 	convolutional (0.13533020570191268)
# 	different (0.2702995308552869)
# 	recognition (0.13641284734752795)
#
# Some Statistics words are:
# 	convergence (0.1256776737309019)
# 	statistical (0.14637752587481517)
# 	variables (0.13701330704780681)
# 	distribution (0.17052735337604732)
# 	theoretical (0.14982750123213406)
# 	algorithm (0.38442582552981763)
# 	estimation (0.17989157220305568)
# 	dimensional (0.19270576638738296)
# 	inference (0.1981271562345983)
# 	regression (0.18284869393790043)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2bc32c00-4e32-475a-89e2-7654b83a4442" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bc32c00-4e32-475a-89e2-7654b83a4442")) {                    Plotly.newPlot(                        "2bc32c00-4e32-475a-89e2-7654b83a4442",                        [{"x":["parameters","stochastic","considering","likelihood","experiments","effectiveness","recording","dependent","algorithm","harnesses","outperforming","algorithms","synthetic","assumption","significantly","demonstrate","dependencies","representation","challenges","inference","structures","benchmarks","including","demonstrates","likelihoods","probabilistic","structure","observations","generative","literature","feasibility","unsupervised","representations","establish","underlying","mathematical","conditions","continuity","suggested","recurrent","limitations","achievement","illustrate","condition","definition","manuscript","lipschitz","connectivity","sufficient","determining","functions","sequential","alternative","formulation","properties","processes","distributions","connections","clustering","exchangeability","partitions","performance","nonparametric","restaurant","traditional","precision","knowledge","automatically","generated","consumption","evaluation","connected","identifying","arrangement","variables","typically","introduce","available","unfortunately","extracting","challenging","technique","prediction","dynamically","coefficients","presented","segmentation","regularities","different","adjusting","discretization","extraction","conceptual","incremental","resulting","hierarchical","complexity","statistical","instantaneous","frequency","isolation","robustness","instantaneously","detection","boltzmann","introduced","increased","importantly","computational","consequence","ubiquitous","regression","extensive","producing","essentially","recursive","splitting","framework","validation","manifests","simulation","validated","categorical","approaches","fundamental","predictive","following","selection","performing","contribute","important","assumptions","classification","inability","reasonable","categories","selecting","partitioning","replacing","informative","overfitting","precludes","factorization","filtering","collaborative","simplicity","exploiting","bandwidth","dimensional","recommendations","connection","efficient","differential","implementation","posterior","differentially","increases","applications","conventional","information","discrimination","indicates","categorization","divergence","monotonically","potential","generalization","numerically","tightness","approximations","techniques","approximation","maximizing","submodular","increasing","submodularity","variational","constrained","distribution","decomposes","maximized","treewidth","relationship","extensions","factorizing","relaxation","difference","guarantees","graphical","minimized","entropies","preparing","egocentric","appearance","assistive","distinguishes","interactions","collected","indicating","displayed","initialising","discovers","recommend","attention","investigates","triggered","discovered","combination","leveraging","constants","particular","shrinkage","guarantee","implementations","variation","compressed","regularization","heuristics","additionally","experimental","thousands","strategies","restarting","continuation","currently","backtracks","regarding","collection","characterized","indicators","describing","personality","preferences","dirichlet","entertainment","preferred","correlations","significant","ameliorate","experience","positively","confirmed","recommendation","describes","intuitive","leveraged","correlated","allocation","comprised","international","interested","conjunction","uncertainty","forecasting","implications" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	precludes
# 	terabytes
# 	metabolites
# 	repertoires
# 	crowdworkers
# 	penalization
# 	suppresses
# 	deterioration
# 	distributedly
# 	looseness
# 	advocates
# 	infectious
# 	timestamps
# 	unobservable
# 	whitening
# 	eigendecomposition
# 	thermostats
# 	integrator
# 	personalised
# 	compromises
# Some words which never appear in Statistics papers:
# 	achievement
# 	treewidth
# 	factorizing
# 	egocentric
# 	assistive
# 	triggered
# 	backtracks
# 	entertainment
# 	elasticity
# 	disruptions
# 	colloquial
# 	sentimental
# 	homography
# 	fixations
# 	congestion
# 	transformer
# 	defeasible
# 	suggestive
# 	somewhere
# 	transposition

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.099237587553462e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7808333333333334
